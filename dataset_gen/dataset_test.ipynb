# %%
import numpy as np
data = np.load("/data/user_data/vhsingh/LDC_hole_location/batch_0/2results_batch_1.npy")
print(data.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 data = np.load("/data/user_data/vhsingh/LDC_hole_location/batch_0/2results_batch_1.npy")
#       3 print(data.shape)
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/user_data/vhsingh/LDC_hole_location/batch_0/2results_batch_1.npy'
