# %%
import numpy.lib.format as fmt

path = "/data/group_data/sage_lab_complex_geometry/FPO_data/FPO_Multiple_Hole_Regularized_10240.npy"
with open(path, 'rb') as f:
    # read magic/version
    version = fmt.read_magic(f)
    # read header (shape, fortran_order, dtype)
    shape, _, _ = fmt._read_array_header(f, version)
print("Shape from header only:", shape)
# Out:
# Shape from header only: (10240, 20, 128, 128, 6)
